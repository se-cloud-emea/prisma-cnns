# %% [markdown]
# # CNNS Audit Events 2 Firewall Rules Generator v1.0

# %% [markdown]
# #### Author: Piotr Jablonski, pijablonski@paloaltonetworks.com
# #### 11 Nov 2022

# %% [markdown]
# ## Initial import

# %%
import json
import pandas as pd

# For Python 2+3 with Unicode
import io
try:
    to_unicode = unicode
except NameError:
    to_unicode = str

# %% [markdown]
# ## File variables

# %%
file_in = "INSERT_FILE_NAME.csv"
file_result = "INSERT_FILE_NAME.json"

# Available options:
# "allow"
# "alert"
# "prevent"
rule_effect = "alert"

# %% [markdown]
# ## Importing firewall audit events

# %%
data_in = pd.read_csv(file_in)
df = pd.DataFrame(data_in)

# %%
#df = df.head(10)
df
# Out:
#      SrcContainerName                                       SrcImageName  \
# 0                 NaN                        weaveworksdemos/carts:0.4.8
# 1                 NaN  registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...
# 2                 NaN  gcr.io/cto-demos-245420/demo-build/nginx-ingre...
# 3                 NaN  gcr.io/cto-demos-245420/demo-build/nginx-ingre...
# 4                 NaN  gcr.io/cto-demos-245420/demo-build/nginx-ingre...
# ..                ...                                                ...
# 183               NaN             gke.gcr.io/event-exporter:v0.3.5-gke.0
# 184               NaN             gke.gcr.io/event-exporter:v0.3.9-gke.0
# 185               NaN  us-docker.pkg.dev/google-samples/containers/gk...
# 186               NaN          docker.io/kbudde/rabbitmq-exporter:latest
# 187               NaN                  docker.io/prom/prometheus:v2.26.0
#
#                                       DstContainerName  \
# 0    /k8s_carts-db_carts-db-64ff6c747f-d5psc_sock-s...
# 1    /k8s_twistlock-console_twistlock-console-7cbb6...
# 2    /k8s_twistlock-console_twistlock-console-7cbb6...
# 3    /k8s_twistlock-console_twistlock-console-7cbb6...
# 4                                                  NaN
# ..                                                 ...
# 183                                     event-exporter
# 184                                     event-exporter
# 185                                           follower
# 186                                  rabbitmq-exporter
# 187                                  rabbitmq-exporter
#
#                                           DstImageName   Port  Block Message  \
# 0                                         mongo:latest  27017   True     NaN
# 1    registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...  27017  False     NaN
# 2    registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...   8084   True     NaN
# 3    registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...   8083   True     NaN
# 4                                                  NaN     53   True     NaN
# ..                                                 ...    ...    ...     ...
# 183             gke.gcr.io/event-exporter:v0.3.5-gke.0   8080  False     NaN
# 184             gke.gcr.io/event-exporter:v0.3.9-gke.0   8080  False     NaN
# 185  us-docker.pkg.dev/google-samples/containers/gk...   6379  False     NaN
# 186          docker.io/kbudde/rabbitmq-exporter:latest   4369  False     NaN
# 187          docker.io/kbudde/rabbitmq-exporter:latest   9090  False     NaN
#
#      Custom Labels                     Date
# 0              NaN  2022-10-13 14:42:44.532
# 1              NaN  2022-11-08 13:48:37.743
# 2              NaN  2022-10-19 15:15:12.995
# 3              NaN  2022-10-13 15:08:09.292
# 4              NaN  2022-10-13 15:12:20.863
# ..             ...                      ...
# 183            NaN  2022-11-11 04:29:01.514
# 184            NaN  2022-11-11 04:29:51.223
# 185            NaN  2022-11-11 06:30:14.417
# 186            NaN  2022-11-11 11:09:59.204
# 187            NaN  2022-11-11 11:09:34.775
#
# [188 rows x 9 columns]

# %%
df2 = df[df['Block'] == False]
df2
# Out:
#      SrcContainerName                                       SrcImageName  \
# 1                 NaN  registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...
# 8                 NaN                           k8s.gcr.io/coredns:1.6.5
# 9                 NaN                           k8s.gcr.io/coredns:1.6.5
# 10                NaN  mcr.microsoft.com/aks/hcp/hcp-tunnel-front:mas...
# 11                NaN  mcr.microsoft.com/aks/hcp/hcp-tunnel-front:mas...
# ..                ...                                                ...
# 183               NaN             gke.gcr.io/event-exporter:v0.3.5-gke.0
# 184               NaN             gke.gcr.io/event-exporter:v0.3.9-gke.0
# 185               NaN  us-docker.pkg.dev/google-samples/containers/gk...
# 186               NaN          docker.io/kbudde/rabbitmq-exporter:latest
# 187               NaN                  docker.io/prom/prometheus:v2.26.0
#
#                                       DstContainerName  \
# 1    /k8s_twistlock-console_twistlock-console-7cbb6...
# 8    /k8s_coredns_coredns-6955765f44-nnnkt_kube-sys...
# 9    /k8s_coredns_coredns-6955765f44-rcjqv_kube-sys...
# 10                                             coredns
# 11                                             coredns
# ..                                                 ...
# 183                                     event-exporter
# 184                                     event-exporter
# 185                                           follower
# 186                                  rabbitmq-exporter
# 187                                  rabbitmq-exporter
#
#                                           DstImageName   Port  Block Message  \
# 1    registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...  27017  False     NaN
# 8                             k8s.gcr.io/coredns:1.6.5   8080  False     NaN
# 9                             k8s.gcr.io/coredns:1.6.5   8080  False     NaN
# 10     mcr.microsoft.com/oss/kubernetes/coredns:v1.8.7   9153  False     NaN
# 11     mcr.microsoft.com/oss/kubernetes/coredns:v1.8.7   9153  False     NaN
# ..                                                 ...    ...    ...     ...
# 183             gke.gcr.io/event-exporter:v0.3.5-gke.0   8080  False     NaN
# 184             gke.gcr.io/event-exporter:v0.3.9-gke.0   8080  False     NaN
# 185  us-docker.pkg.dev/google-samples/containers/gk...   6379  False     NaN
# 186          docker.io/kbudde/rabbitmq-exporter:latest   4369  False     NaN
# 187          docker.io/kbudde/rabbitmq-exporter:latest   9090  False     NaN
#
#      Custom Labels                     Date
# 1              NaN  2022-11-08 13:48:37.743
# 8              NaN  2022-11-07 17:27:23.907
# 9              NaN  2022-11-07 17:27:23.666
# 10             NaN  2022-11-07 17:29:40.808
# 11             NaN  2022-11-07 17:27:56.666
# ..             ...                      ...
# 183            NaN  2022-11-11 04:29:01.514
# 184            NaN  2022-11-11 04:29:51.223
# 185            NaN  2022-11-11 06:30:14.417
# 186            NaN  2022-11-11 11:09:59.204
# 187            NaN  2022-11-11 11:09:34.775
#
# [181 rows x 9 columns]

# %% [markdown]
# ## Extracting unique image names

# %%
df3 = pd.DataFrame()
df4 = pd.DataFrame()
image_df = pd.DataFrame()

df3['ImageName'] = df2['SrcImageName']
df4['ImageName'] = df2['DstImageName']
image_df = pd.concat([df3,df4]).drop_duplicates()
image_df = image_df.reset_index(drop=True)
image_df
# Out:
#                                             ImageName
# 0   registry-auth.twistlock.com/tw_dsrywt19ny0eqyc...
# 1                            k8s.gcr.io/coredns:1.6.5
# 2   mcr.microsoft.com/aks/hcp/hcp-tunnel-front:mas...
# 3     mcr.microsoft.com/oss/kubernetes/coredns:v1.8.7
# 4   mcr.microsoft.com/oss/kubernetes/apiserver-net...
# ..                                                ...
# 75    gcr.io/cto-demos-245420/demo-build/nexus:latest
# 76                openfrontier/openldap-server:latest
# 77                              dnknth/ldap-ui:latest
# 78     gcr.io/cto-demos-245420/demo-build/mail:latest
# 79  us-docker.pkg.dev/google-samples/containers/gk...
#
# [80 rows x 1 columns]

# %% [markdown]
# ## Start-up json template

# %%
data = {
    "_id": "networkFirewall",
    "hostEnabled": True,
    "hostRules": [],
    "containerEnabled": True,
    "containerRules": [],
    "networkEntities": []
}

# %% [markdown]
# ## Generating firewall rules

# %%
#print(image_df)
for row in df2.itertuples():
    #print("No.", row.Index, " :" ,df2.loc[row.Index,'DstImageName'])
    
    #print(df2.loc[row.Index,"SrcImageName"])
    #df.index[df['column_name']==value].tolist()
    if df2.loc[row.Index,'SrcImageName'] in image_df['ImageName'].values :
        src = image_df.index[image_df['ImageName'] == df2.loc[row.Index,'SrcImageName']].tolist()
        #print(src)

    if df2.loc[row.Index,'DstImageName'] in image_df['ImageName'].values :
        dst = image_df.index[image_df['ImageName'] == df2.loc[row.Index,'DstImageName']].tolist()
        #print(dst)

    rulex = {
            "id": row.Index,
            "src": src[0]+100,
            "dst": dst[0]+100,
            "ports": [
                {
                    "start": row.Port,
                    "end": row.Port,
                    "deny": False
                }
            ],
            "effect": rule_effect
        }
    #print(rulex)
    
    data['containerRules'].append(rulex)

print(data)
# Out:
# {'_id': 'networkFirewall', 'hostEnabled': True, 'hostRules': [], 'containerEnabled': True, 'containerRules': [{'id': 1, 'src': 100, 'dst': 100, 'ports': [{'start': 27017, 'end': 27017, 'deny': False}], 'effect': 'alert'}, {'id': 8, 'src': 101, 'dst': 101, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 9, 'src': 101, 'dst': 101, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 10, 'src': 102, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 11, 'src': 102, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 12, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 13, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 14, 'src': 104, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 15, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 16, 'src': 104, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 17, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 18, 'src': 101, 'dst': 101, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 19, 'src': 102, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 20, 'src': 102, 'dst': 103, 'ports': [{'start': 9153, 'end': 9153, 'deny': False}], 'effect': 'alert'}, {'id': 21, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 22, 'src': 103, 'dst': 103, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 23, 'src': 105, 'dst': 105, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 24, 'src': 105, 'dst': 105, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 25, 'src': 106, 'dst': 106, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 26, 'src': 107, 'dst': 107, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 27, 'src': 108, 'dst': 108, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 28, 'src': 109, 'dst': 109, 'ports': [{'start': 15001, 'end': 15001, 'deny': False}], 'effect': 'alert'}, {'id': 29, 'src': 109, 'dst': 109, 'ports': [{'start': 15000, 'end': 15000, 'deny': False}], 'effect': 'alert'}, {'id': 30, 'src': 110, 'dst': 109, 'ports': [{'start': 15020, 'end': 15020, 'deny': False}], 'effect': 'alert'}, {'id': 31, 'src': 109, 'dst': 109, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 32, 'src': 111, 'dst': 109, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 33, 'src': 112, 'dst': 112, 'ports': [{'start': 4369, 'end': 4369, 'deny': False}], 'effect': 'alert'}, {'id': 34, 'src': 113, 'dst': 114, 'ports': [{'start': 9090, 'end': 9090, 'deny': False}], 'effect': 'alert'}, {'id': 35, 'src': 114, 'dst': 114, 'ports': [{'start': 4369, 'end': 4369, 'deny': False}], 'effect': 'alert'}, {'id': 36, 'src': 104, 'dst': 154, 'ports': [{'start': 4443, 'end': 4443, 'deny': False}], 'effect': 'alert'}, {'id': 37, 'src': 114, 'dst': 114, 'ports': [{'start': 4369, 'end': 4369, 'deny': False}], 'effect': 'alert'}, {'id': 38, 'src': 115, 'dst': 115, 'ports': [{'start': 42699, 'end': 42699, 'deny': False}], 'effect': 'alert'}, {'id': 39, 'src': 116, 'dst': 116, 'ports': [{'start': 8080, 'end': 8080, 'deny': False}], 'effect': 'alert'}, {'id': 40, 'src': 117, 'dst': 117, 'ports': [{'start': 80, 'end': 80, 'deny': False}], 'effect': 'alert'}, {'id': 41, 'src': 118, 'dst': 118, 'ports': [{'start': 4369, 'end': 4369, 'deny': False}], 'effect': 'alert'}, {' ...

# %% [markdown]
# ## Generating collections

# %%
    
for i, row in image_df.itertuples():
    #print(i, " :" ,row)
    name = row.replace('/', '_') 
    name = name.replace('.', '-')
    print(name)
    data_rule = {
            "_id": i+100,
            "name": name,
            "type": "container",
            "collections": [
                {
                    "hosts": [
                        "*"
                    ],
                    "images": [
                        row
                    ],
                    "labels": [
                        "*"
                    ],
                    "containers": [
                        "*"
                    ],
                    "functions": [
                        "*"
                    ],
                    "namespaces": [
                        "*"
                    ],
                    "appIDs": [
                        "*"
                    ],
                    "accountIDs": [
                        "*"
                    ],
                    "codeRepos": [
                        "*"
                    ],
                    "clusters": [
                        "*"
                    ],
                    "name": name,
                    "system": False,
                    "prisma": False
                }
            ]
            }

    data['networkEntities'].append(data_rule)
    
    #data['networkEntities'][0]['collections'][0]['images'] = row
# Out:
# registry-auth-twistlock-com_tw_dsrywt19ny0eqycsbztpfbz8jsojhq9v_twistlock_console:console_22_06_179
# k8s-gcr-io_coredns:1-6-5
# mcr-microsoft-com_aks_hcp_hcp-tunnel-front:master-220527-2
# mcr-microsoft-com_oss_kubernetes_coredns:v1-8-7
# mcr-microsoft-com_oss_kubernetes_apiserver-network-proxy_agent:v0-0-30
# 602401143452-dkr-ecr-us-east-1-amazonaws-com_eks_coredns:v1-8-4-eksbuild-1
# 602401143452-dkr-ecr-ap-southeast-1-amazonaws-com_eks_coredns:v1-8-7-eksbuild-2
# 602401143452-dkr-ecr-us-east-2-amazonaws-com_eks_coredns:v1-8-7-eksbuild-1
# 602401143452-dkr-ecr-us-west-2-amazonaws-com_eks_coredns:v1-8-7-eksbuild-1
# docker-io_richardchesterwood_istio-fleetman-position-tracker:5
# docker-io_prom_prometheus:v2-21-0
# docker-io_richardchesterwood_istio-fleetman-position-simulator:5
# rabbitmq:3-6-8
# docker-io_prom_prometheus:v2-26-0
# docker-io_library_rabbitmq:3-6-8-management
# docker-io_robotshop_rs-web:latest
# 602401143452-dkr-ecr-eu-west-1-amazonaws-com_eks_coredns:v1-7-0-eksbuild-1
# us-docker-pkg-dev_google-samples_containers_gke_gb-frontend:v5
# docker-io_library_rabbitmq:3-7-management-alpine
# istio_examples-bookinfo-reviews-v1:1-16-2
# istio_examples-bookinfo-ratings-v1:1-16-2
# istio_examples-bookinfo-details-v1:1-16-2
# istio_examples-bookinfo-productpage-v1:1-16-2
# istio_examples-bookinfo-reviews-v2:1-16-2
# docker-io_weaveworksdemos_queue-master:0-3-1
# docker-io_kbudde_rabbitmq-exporter:latest
# rbenavente_gb-frontend-cns:v1
# gke-gcr-io_proxy-agent:v0-0-31-gke-0
# docker-io_richardchesterwood_istio-fleetman-webapp-angular:5
# docker-io_richardchesterwood_istio-fleetman-vehicle-telemetry:5
# docker-io_richardchesterwood_istio-fleetman-staff-service:5
# docker-io_richardchesterwood_istio-fleetman-api-gateway:5
# gke-gcr-io_event-exporter:v0-3-10-gke-0
# mcr-microsoft-com_azuredocs_azure-vote-front:v1
# istio_examples-bookinfo-reviews-v3:1-16-2
# docker-io_weaveworksdemos_front-end:0-3-12
# gke-gcr-io_prometheus-to-sd:v0-11-3-gke-0
# gogs_gogs:0-12-9
# gcr-io_cto-demos-245420_demo-build_splunk:latest
# docker-io_richardchesterwood_istio-fleetman-photo-service:5
# gcr-io_cto-demos-245420_demo-build_nginx-ingress-controller:0-24-1
# nodeasset-azurecr-io_algo-pub:latest
# nodeasset-azurecr-io_rabbitmq:latest
# nodeasset-azurecr-io_algo-orderer:latest
# nodeasset-azurecr-io_algo-ibgateway:latest
# docker-io_grafana_grafana:9-1-7
# docker-io_weaveworksdemos_user:0-4-7
# gke-gcr-io_istio_galley:1-4-10-gke-21
# gke-gcr-io_istio_mixer:1-4-10-gke-21
# docker-io_weaveworksdemos_catalogue:0-3-5
# 602401143452-dkr-ecr-us-east-1-amazonaws-com_eks_coredns:v1-8-7-eksbuild-1
# docker-io_kubernetesui_dashboard:v2-6-1
# gke-gcr-io_event-exporter:v0-3-5-gke-0
# gke-gcr-io_event-exporter:v0-3-9-gke-0
# mcr-microsoft-com_oss_kubernetes_metrics-server:v0-5-2
# istio_pilot:1-8-1
# asia-gcr-io_gke-release-staging_metrics-server-amd64:v0-4-5-gke-0
# docker-io_istio_pilot:1-10-3
# mcr-microsoft-com_oss_kubernetes_metrics-server:v0-4-5
# gke-gcr-io_metrics-server:v0-5-2-gke-1
# mcr-microsoft-com_oss_kubernetes_metrics-server:v0-3-6
# docker-io_weaveworksdemos_orders:0-4-7
# docker-io_weaveworksdemos_shipping:0-4-8
# docker-io_weaveworksdemos_carts:0-4-8
# docker-io_jaegertracing_all-in-one:1-20
# quay-io_prometheus-operator_prometheus-config-reloader:v0-60-1
# vault:0-9-6
# docker-io_weaveworksdemos_user-db:0-3-0
# docker-io_weaveworksdemos_catalogue-db:0-3-0
# docker-io_weaveworksdemos_payment:0-4-3
# docker-io_library_redis:alpine
# k8s-gcr-io_kube-state-metrics_kube-state-metrics:v2-1-0
# docker-io_dockermuenster_caddy:0-9-3
# docker-io_giantswarm_tiny-tools:latest
# postgres:10-6
# gcr-io_cto-demos-245420_demo-build_nexus:latest
# openfrontier_openldap-server:latest
# dnknth_ldap-ui:latest
# gcr-io_cto-demos-245420_demo-build_mail:latest
# us-docker-pkg-dev_google-samples_containers_gke_gb-redis-follower:v2

# %% [markdown]
# ## Saving the output to a JSON file

# %%
with io.open(file_result, 'w', encoding='utf8') as outfile:
    str_ = json.dumps(data, indent=4, sort_keys=True, separators=(',', ': '), ensure_ascii=False)
    outfile.write(to_unicode(str_))
